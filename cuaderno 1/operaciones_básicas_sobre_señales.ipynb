# %% [markdown]
# <a href="https://colab.research.google.com/github/LyaRB/SenalesySistemas/blob/main/cuaderno%201/operaciones_b%C3%A1sicas_sobre_se%C3%B1ales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# si tenemos dos señales definidas como
# h = sym.exp(-t) * sym.Heaviside(t)
# x = rect(t - 1/2)

# %% [markdown]
# para la inversión temporal

# %%
print("primer paso")
h1 = h.subs(t, tau)
x1 = x.subs(t, tau)

# %% [markdown]
# para desplazamiento temporal

# %%
print("segundo paso")

h2 = h1.subs(tau, -tau)

# %% [markdown]
# con lo anterior estamos asegurando que haya una inversión y un desplazamiento.
# Ejemplo

# %% [markdown]
# Convolución
# Ejercicio

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sym
from sympy import *

# %%
# %matplotlib inline
import sympy as sym
sym.init_printing()

t, tau = sym.symbols('t tau', real=True)#variables simbólicas
class rect(sym.Function): #función pulso rectangular
    @classmethod
    def eval(cls, arg):
        return sym.Heaviside(arg + sym.S.Half) - sym.Heaviside(arg - sym.S.Half)

def plot_signals(x_axis, x, h, ylabel, xlabel):#función para graficar convolución
    p1 = sym.plot(x, (x_axis, -5, 5), show=False, line_color='b', ylabel=ylabel, xlabel=xlabel)
    p2 = sym.plot(h, (x_axis, -5, 5), show=False, line_color='r')
    p1.extend(p2)
    p1.show()

# %%
h = sym.exp(-t) * sym.Heaviside(t)
x = rect(t - 1/2)

plot_signals(t, x, h, r'$h(t)$, $x(t)$', r'$t$')

# %%
print("primer paso")
h1 = h.subs(t, tau)
x1 = x.subs(t, tau)

plot_signals(tau, x1, h1, r'$h(\tau)$, $x(\tau)$', r'$\tau$')
# Out:
# primer paso

# %%
print("segundo paso")

h2 = h1.subs(tau, -tau)

plot_signals(tau, x1, h2, r'$h(-\tau)$, $x(\tau)$', r'$\tau$')
# Out:
# segundo paso

# %%
print("tercer paso")

h3 = h2.subs(tau, tau-t)

plot_signals(tau, x1, h3.subs(t, -2), r'$h(t-\tau)$, $x(\tau)$', r'$\tau$')
# Out:
# tercer paso
