# %% [markdown]
# <a href="https://colab.research.google.com/github/LyaRB/SenalesySistemas/blob/main/Transformada%20de%20Laplace/Transformada_inversa_de_Laplace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Calcular la transformada inversa de L^-1 {1/(s+1)(s+2)^2}

# %% [markdown]
# ![Transformada inversa.jpeg](data:image/jpeg;base64,...)

# %%
import sympy as sym
# %matplotlib inline

# %%
s = sym.symbols('s', complex=True)
t = sym.symbols('t', real=True)

X = (1/((s+1)*(s+2)**2))
X
# Out:
# 1/((s + 1)*(s + 2)**2)

# %%
polos = sym.roots(sym.denom(X))
polos
# Out:
# {-1: 1, -2: 2}

# %%
x1 = sym.inverse_laplace_transform(X, s, t)
x1
# Out:
# -t*exp(-2*t)*Heaviside(t) + exp(-t)*Heaviside(t) - exp(-2*t)*Heaviside(t)

# %%
sym.plot(x1, (t, 0, 10), xlabel = '$t$', ylabel = '$x(t)$');
